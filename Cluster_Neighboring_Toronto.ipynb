# %% [markdown]
# ## Load and Preprocess Dataframe

# %% [markdown]
# #### import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### read dataframe via url, and have an initial view

# %%
d = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')
df = d[0]

# %%
df.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
df.nunique()
# Out:
# Postal code     180
# Borough          11
# Neighborhood     98
# dtype: int64

# %% [markdown]
# #### Clean data:
# 1. check if 'Not assigned' in Borough has Neighborhood
# 2. if yes, assign Borough
# 3. remove the 'Not assigned' columns in Borough
# 4. merge the Neighborhood with the same Borough

# %%
df[df['Borough']=='Not assigned']
# Out:
#     Postal code       Borough Neighborhood
# 0           M1A  Not assigned          NaN
# 1           M2A  Not assigned          NaN
# 7           M8A  Not assigned          NaN
# 10          M2B  Not assigned          NaN
# 15          M7B  Not assigned          NaN
# ..          ...           ...          ...
# 174         M4Z  Not assigned          NaN
# 175         M5Z  Not assigned          NaN
# 176         M6Z  Not assigned          NaN
# 177         M7Z  Not assigned          NaN
# 179         M9Z  Not assigned          NaN
#
# [77 rows x 3 columns]

# %%
df.drop(df[df['Borough']=='Not assigned'].index, inplace=True)

# %%
df.columns = ['Postalcode','Borough','Neighborhood'] # change column names

# %%
df.reset_index(drop=True, inplace=True) # reset indexes

# %%
df['Postalcode'].nunique() # the Wiki page has been updated and no need to merge the Neighborhood with the same Postalcode
# Out:
# 103

# %%
df['Neighborhood'] = df['Neighborhood'].apply(lambda x: eval(repr(x).replace(' / ', ', ')))

# %%
df.head()
# Out:
#   Postalcode           Borough                                 Neighborhood
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Add location information

# %%
# !pip install geocoder 
import geocoder # import geocoder
# Out:
# Looking in indexes: http://pypi.douban.com/simple
# Requirement already satisfied: geocoder in d:\acanconda\lib\site-packages (1.38.1)
# Requirement already satisfied: ratelim in d:\acanconda\lib\site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in d:\acanconda\lib\site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: future in d:\acanconda\lib\site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: click in d:\acanconda\lib\site-packages (from geocoder) (7.0)
# Requirement already satisfied: six in d:\acanconda\lib\site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: decorator in d:\acanconda\lib\site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\acanconda\lib\site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\acanconda\lib\site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in d:\acanconda\lib\site-packages (from requests->geocoder) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\acanconda\lib\site-packages (from requests->geocoder) (1.24.2)

# %%
# all postal codes
postal_codes = df['Postalcode']
postal_codes
# Out:
# 0      M3A
# 1      M4A
# 2      M5A
# 3      M6A
# 4      M7A
#       ...
# 98     M8X
# 99     M4Y
# 100    M7Y
# 101    M8Y
# 102    M8Z
# Name: Postalcode, Length: 103, dtype: object

# %% [markdown]
# #### find the location information by using geocoder

# %%
# It takes too long to get the latitude and longitude information using geocoder, here only gices the code but not excuted.
# The location information is added by using the provided csv file.

latitude = []
longitude = []

for postal_code in postal_codes:
    # initialize your variable to None
    lat_lng_coords = None

    # loop until you get the coordinates
    while(lat_lng_coords is None):
      g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
      lat_lng_coords = g.latlng

    latitude = latitude.append(lat_lng_coords[0])
    longitude = longitude.append(lat_lng_coords[1])

df['Latitude'] = latitude
df['Longitude'] = longitude
df.head()

# %% [markdown]
# #### find the location information by using the provided csv

# %%
df_geo = pd.read_csv('Geospatial_Coordinates.csv')

# %%
df_geo.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %%
df_geo.columns = ['Postalcode', 'Latitude','Longitude']

# %%
df_g = pd.merge(df, df_geo, on='Postalcode')
df_g.head(10)
# Out:
#   Postalcode           Borough                                 Neighborhood  \
# 0        M3A        North York                                    Parkwoods
# 1        M4A        North York                             Victoria Village
# 2        M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3        M6A        North York             Lawrence Manor, Lawrence Heights
# 4        M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# 5        M9A         Etobicoke                             Islington Avenue
# 6        M1B       Scarborough                               Malvern, Rouge
# 7        M3B        North York                                    Don Mills
# 8        M4B         East York              Parkview Hill, Woodbine Gardens
# 9        M5B  Downtown Toronto                     Garden District, Ryerson
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494
# 5  43.667856 -79.532242
# 6  43.806686 -79.194353
# 7  43.745906 -79.352188
# 8  43.706397 -79.309937
# 9  43.657162 -79.378937

# %%
df_g['Borough'].unique()
# Out:
# array(['North York', 'Downtown Toronto', 'Etobicoke', 'Scarborough',
#        'East York', 'York', 'East Toronto', 'West Toronto',
#        'Central Toronto', 'Mississauga'], dtype=object)

# %% [markdown]
# # Clustering the neighborhoods

# %%
# libraries import
from sklearn.cluster import KMeans
import matplotlib.cm as cm
import matplotlib.colors as colors
import json
import requests # library to handle requests
from pandas.io.json import json_normalize

# !pip install folium
import folium

# !pip install geopy
from geopy.geocoders import Nominatim
# Out:
# Looking in indexes: http://pypi.douban.com/simple
# Requirement already satisfied: folium in d:\acanconda\lib\site-packages (0.10.1)
# Requirement already satisfied: requests in d:\acanconda\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in d:\acanconda\lib\site-packages (from folium) (2.10.3)
# Requirement already satisfied: numpy in d:\acanconda\lib\site-packages (from folium) (1.16.5)
# Requirement already satisfied: branca>=0.3.0 in d:\acanconda\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in d:\acanconda\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\acanconda\lib\site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\acanconda\lib\site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in d:\acanconda\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\acanconda\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: six in d:\acanconda\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Looking in indexes: http://pypi.douban.com/simple
# Requirement already satisfied: geopy in d:\acanconda\lib\site-packages (1.21.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in d:\acanconda\lib\site-packages (from geopy) (1.50)

# %%
print('The dataframe has {} boroughs and {} neighborhoods.'.format(
        len(df_g['Borough'].unique()),
        df_g.shape[0]
    )
)
# Out:
# The dataframe has 10 boroughs and 103 neighborhoods.

# %% [markdown]
# Map of Toronto

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_g['Latitude'], df_g['Longitude'], df_g['Borough'], df_g['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Use 'York' as the targeting borough for clustering

# %%
york_data = df_g[df_g['Borough'].str.contains('York', regex=False)].reset_index(drop=True)
york_data
# Out:
#    Postalcode     Borough                                      Neighborhood  \
# 0         M3A  North York                                         Parkwoods
# 1         M4A  North York                                  Victoria Village
# 2         M6A  North York                  Lawrence Manor, Lawrence Heights
# 3         M3B  North York                                         Don Mills
# 4         M4B   East York                   Parkview Hill, Woodbine Gardens
# 5         M6B  North York                                         Glencairn
# 6         M3C  North York                                         Don Mills
# 7         M4C   East York                                  Woodbine Heights
# 8         M6C        York                                Humewood-Cedarvale
# 9         M6E        York                               Caledonia-Fairbanks
# 10        M4G   East York                                           Leaside
# 11        M2H  North York                                 Hillcrest Village
# 12        M3H  North York   Bathurst Manor, Wilson Heights, Downsview North
# 13        M4H   East York                                  Thorncliffe Park
# 14        M2J  North York                      Fairview, Henry Farm, Oriole
# 15        M3J  North York                   Northwood Park, York University
# 16        M4J   East York                                      East Toronto
# 17        M2K  North York                                   Bayview Village
# 18        M3K  North York                                         Downsview
# 19        M2L  North York                          York Mills, Silver Hills
# 20        M3L  North York                                         Downsview
# 21        M6L  North York          North Park, Maple Leaf Park, Upwood Park
# 22        M9L  North York                                     Humber Summit
# 23        M2M  North York                           Willowdale, Newtonbrook
# 24        M3M  North York                                         Downsview
# 25        M5M  North York                 Bedford Park, Lawrence Manor East
# 26        M6M        York  Del Ray, Mount Dennis, Keelsdale and Silverthorn
# 27        M9M  North York                                  Humberlea, Emery
# 28        M2N  North York                                        Willowdale
# 29        M3N  North York                                         Downsview
# 30        M6N        York                     Runnymede, The Junction North
# 31        M9N        York                                            Weston
# 32        M2P  North York                                   York Mills West
# 33        M2R  North York                                        Willowdale
#
#      Latitude  Longitude
# 0   43.753259 -79.329656
# 1   43.725882 -79.315572
# 2   43.718518 -79.464763
# 3   43.745906 -79.352188
# 4   43.706397 -79.309937
# 5   43.709577 -79.445073
# 6   43.725900 -79.340923
# 7   43.695344 -79.318389
# 8   43.693781 -79.428191
# 9   43.689026 -79.453512
# 10  43.709060 -79.363452
# 11  43.803762 -79.363452
# 12  43.754328 -79.442259
# 13  43.705369 -79.349372
# 14  43.778517 -79.346556
# 15  43.767980 -79.487262
# 16  43.685347 -79.338106
# 17  43.786947 -79.385975
# 18  43.737473 -79.464763
# 19  43.757490 -79.374714
# 20  43.739015 -79.506944
# 21  43.713756 -79.490074
# 22  43.756303 -79.565963
# 23  43.789053 -79.408493
# 24  43.728496 -79.495697
# 25  43.733283 -79.419750
# 26  43.691116 -79.476013
# 27  43.724766 -79.532242
# 28  43.770120 -79.408493
# 29  43.761631 -79.520999
# 30  43.673185 -79.487262
# 31  43.706876 -79.518188
# 32  43.752758 -79.400049
# 33  43.782736 -79.442259

# %% [markdown]
# Map of York

# %%
address = 'York, Toronto'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

# create map of York using latitude and longitude values
map_york = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(york_data['Latitude'], york_data['Longitude'], york_data['Borough'], york_data['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_york)  
    
map_york
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Foursquare information

# %%
CLIENT_ID = 'M2T52Z3GBBM4Z35GK5JTJICHN5DRHGSEZYLMEAWYDXH0FIUN' # your Foursquare ID
CLIENT_SECRET = 'DCDIICNCANQTKXUEXRI4FKCAQEKSENHOT0DLJBK403PQYZDN' # your Foursquare Secret
VERSION = '20200330' # Foursquare API version

# %% [markdown]
# The function that finds all neighborhood's venues' latitude and longitude, radius is 500 and limit number is 100.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
york_venues = getNearbyVenues(names = york_data['Neighborhood'],
                                   latitudes=york_data['Latitude'],
                                   longitudes=york_data['Longitude']
                                  ) # The venues in the neighborhood of York.
# Out:
# Parkwoods
# Victoria Village
# Lawrence Manor, Lawrence Heights
# Don Mills
# Parkview Hill, Woodbine Gardens
# Glencairn
# Don Mills
# Woodbine Heights
# Humewood-Cedarvale
# Caledonia-Fairbanks
# Leaside
# Hillcrest Village
# Bathurst Manor, Wilson Heights, Downsview North
# Thorncliffe Park
# Fairview, Henry Farm, Oriole
# Northwood Park, York University
# East Toronto
# Bayview Village
# Downsview
# York Mills, Silver Hills
# Downsview
# North Park, Maple Leaf Park, Upwood Park
# Humber Summit
# Willowdale, Newtonbrook
# Downsview
# Bedford Park, Lawrence Manor East
# Del Ray, Mount Dennis, Keelsdale and Silverthorn
# Humberlea, Emery
# Willowdale
# Downsview
# Runnymede, The Junction North
# Weston
# York Mills West
# Willowdale

# %%
print(york_venues.shape)
york_venues.head()
# Out:
# (333, 7)
#        Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0         Parkwoods              43.753259              -79.329656
# 1         Parkwoods              43.753259              -79.329656
# 2         Parkwoods              43.753259              -79.329656
# 3  Victoria Village              43.725882              -79.315572
# 4  Victoria Village              43.725882              -79.315572
#
#                     Venue  Venue Latitude  Venue Longitude     Venue Category
# 0         Brookbanks Park       43.751976       -79.332140               Park
# 1             649 Variety       43.754513       -79.331942  Convenience Store
# 2           Variety Store       43.751974       -79.333114  Food & Drink Shop
# 3  Victoria Village Arena       43.723481       -79.315635       Hockey Arena
# 4             Tim Hortons       43.725517       -79.313103        Coffee Shop

# %%
york_venues.groupby('Neighborhood').count()  # venues found in each neighborhood
# Out:
#                                                   Neighborhood Latitude  \
# Neighborhood
# Bathurst Manor, Wilson Heights, Downsview North                      20
# Bayview Village                                                       4
# Bedford Park, Lawrence Manor East                                    24
# Caledonia-Fairbanks                                                   4
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                      4
# Don Mills                                                            26
# Downsview                                                            15
# East Toronto                                                          3
# Fairview, Henry Farm, Oriole                                         65
# Glencairn                                                             4
# Hillcrest Village                                                     5
# Humber Summit                                                         2
# Humberlea, Emery                                                      1
# Humewood-Cedarvale                                                    4
# Lawrence Manor, Lawrence Heights                                     12
# Leaside                                                              34
# North Park, Maple Leaf Park, Upwood Park                              4
# Northwood Park, York University                                       5
# Parkview Hill, Woodbine Gardens                                      12
# Parkwoods                                                             3
# Runnymede, The Junction North                                         4
# Thorncliffe Park                                                     20
# Victoria Village                                                      4
# Willowdale                                                           40
# Woodbine Heights                                                      9
# York Mills West                                                       3
# York Mills, Silver Hills                                              2
#
#                                                   Neighborhood Longitude  \
# Neighborhood
# Bathurst Manor, Wilson Heights, Downsview North                       20
# Bayview Village                                                        4
# Bedford Park, Lawrence Manor East                                     24
# Caledonia-Fairbanks                                                    4
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                       4
# Don Mills                                                             26
# Downsview                                                             15
# East Toronto                                                           3
# Fairview, Henry Farm, Oriole                                          65
# Glencairn                                                              4
# Hillcrest Village                                                      5
# Humber Summit                                                          2
# Humberlea, Emery                                                       1
# Humewood-Cedarvale                                                     4
# Lawrence Manor, Lawrence Heights                                      12
# Leaside                                                               34
# North Park, Maple Leaf Park, Upwood Park                               4
# Northwood Park, York University                                        5
# Parkview Hill, Woodbine Gardens                                       12
# Parkwoods                                                              3
# Runnymede, The Junction North                                          4
# Thorncliffe Park                                                      20
# Victoria Village                                                       4
# Willowdale                                                            40
# Woodbine Heights                                                       9
# York Mills West                                                        3
# York Mills, Silver Hills                                               2
#
#                                                   Venue  Venue Latitude  \
# Neighborhood
# Bathurst Manor, Wilson Heights, Downsview North      20              20
# Bayview Village                                       4               4
# Bedford Park, Lawrence Manor East                    24              24
# Caledonia-Fairbanks                                   4               4
# Del Ray, Mount Dennis, Keelsdale and Silverthorn      4               4
# Don Mills                                            26              26
# Downsview                                            15              15
# East Toronto                                          3               3
# Fairview, Henry Farm, Oriole                         65              65
# Glencairn                                             4               4
# Hillcrest Village                                     5               5
# Humber Summit                                         2               2
# Humberlea, Emery                                      1               1
# Humewood-Cedarvale                                    4               4
# Lawrence Manor, Lawrence Heights                     12              12
# Leaside                                              34              34
# North Park, Maple Leaf Park, Upwood Park              4               4
# Northwood Park, York University                       5               5
# Parkview Hill, Woodbine Gardens                      12              12
# Parkwoods                                             3               3
# Runnymede, The Junction North                         4               4
# Thorncliffe Park                                     20              20
# Victoria Village                                      4               4
# Willowdale                                           40              40
# Woodbine Heights                                      9               9
# York Mills West                                       3               3
# York Mills, Silver Hills                              2               2
#
#                                                   Venue Longitude  \
# Neighborhood
# Bathurst Manor, Wilson Heights, Downsview North                20
# Bayview Village                                                 4
# Bedford Park, Lawrence Manor East                              24
# Caledonia-Fairbanks                                             4
# Del Ray, Mount Dennis, Keelsdale and Silverthorn                4
# Don Mills                                                      26
# Downsview                                                      15
# East Toronto                                                    3
# Fairview, Henry Farm, Oriole                                   65
# Glencairn                                                       4
# Hillcrest Village                                               5
# Humber Summit                                                   2
# Humberlea, Emery                                                1
# Humewood-Cedarvale                                              4
# Lawrence Manor, Lawrence Heights                               12
# Leaside                                                        34
# North Park, Maple Leaf Park, Upwood Park                        4
# Northwood Park, York University                                 5
# Parkview Hill, Woodbine Gardens                                12
# Parkwoods                                                       3
# Runnymede, The Junction North                                   4
# Thorncliffe Park                                               20
# Victoria Village                                                4
# Willowdale                                                     40
# Woodbine Heights                                                9
# York Mills West                                                 3
# York Mills, Silver Hills                                        2
#
#                                                   Venue Category
# Neighborhood
# Bathurst Manor, Wilson Heights, Downsview North               20
# Bayview Village                                                4
# Bedford Park, Lawrence Manor East                             24
# Caledonia-Fairbanks                                            4
# Del Ray, Mount Dennis, Keelsdale and Silverthorn               4
# Don Mills                                                     26
# Downsview                                                     15
# East Toronto                                                   3
# Fairview, Henry Farm, Oriole                                  65
# Glencairn                                                      4
# Hillcrest Village                                              5
# Humber Summit                                                  2
# Humberlea, Emery                                               1
# Humewood-Cedarvale                                             4
# Lawrence Manor, Lawrence Heights                              12
# Leaside                                                       34
# North Park, Maple Leaf Park, Upwood Park                       4
# Northwood Park, York University                
# 15     0.000000               0.000000             0.00       0.000000
# 16     0.000000               0.000000             0.00       0.000000
# 17     0.000000               0.000000             0.00       0.000000
# 18     0.000000               0.000000             0.00       0.000000
# 19     0.000000               0.000000             0.00       0.000000
# 20     0.000000               0.000000             0.00       0.000000
# 21     0.000000               0.000000             0.05       0.000000
# 22     0.000000               0.000000             0.00       0.000000
# 23     0.000000               0.025000             0.00       0.000000
# 24     0.111111               0.000000             0.00       0.000000
# 25     0.000000               0.000000             0.00       0.000000
# 26     0.000000               0.000000             0.00       0.000000
#
#     Yoga Studio
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# 5          0.00
# 6          0.00
# 7          0.00
# 8          0.00
# 9          0.00
# 10         0.00
# 11         0.00
# 12         0.00
# 13         0.00
# 14         0.00
# 15         0.00
# 16         0.00
# 17         0.00
# 18         0.00
# 19         0.00
# 20         0.00
# 21         0.05
# 22         0.00
# 23         0.00
# 24         0.00
# 25         0.00
# 26         0.00
#
# [27 rows x 123 columns]

# %%
# print the top 5 most common venues
num_top_venues = 5

for hood in york_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = york_grouped[york_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Bathurst Manor, Wilson Heights, Downsview North----
#               venue  freq
# 0       Coffee Shop  0.10
# 1              Bank  0.10
# 2    Ice Cream Shop  0.05
# 3  Sushi Restaurant  0.05
# 4          Pharmacy  0.05
#
#
# ----Bayview Village----
#                  venue  freq
# 0                 Bank  0.25
# 1  Japanese Restaurant  0.25
# 2   Chinese Restaurant  0.25
# 3                 Café  0.25
# 4       Massage Studio  0.00
#
#
# ----Bedford Park, Lawrence Manor East----
#                 venue  freq
# 0  Italian Restaurant  0.08
# 1         Coffee Shop  0.08
# 2          Restaurant  0.08
# 3      Sandwich Place  0.08
# 4       Grocery Store  0.04
#
#
# ----Caledonia-Fairbanks----
#                venue  freq
# 0               Park  0.50
# 1      Women's Store  0.25
# 2             Market  0.25
# 3  Accessories Store  0.00
# 4       Liquor Store  0.00
#
#
# ----Del Ray, Mount Dennis, Keelsdale and Silverthorn----
#                 venue  freq
# 0         Coffee Shop  0.25
# 1  Turkish Restaurant  0.25
# 2      Sandwich Place  0.25
# 3      Discount Store  0.25
# 4   Accessories Store  0.00
#
#
# ----Don Mills----
#                  venue  freq
# 0           Restaurant  0.08
# 1  Japanese Restaurant  0.08
# 2          Coffee Shop  0.08
# 3                  Gym  0.08
# 4           Beer Store  0.08
#
#
# ----Downsview----
#             venue  freq
# 0   Grocery Store  0.13
# 1            Park  0.13
# 2  Baseball Field  0.07
# 3           Hotel  0.07
# 4         Airport  0.07
#
#
# ----East Toronto----
#                venue  freq
# 0  Convenience Store  0.33
# 1               Park  0.33
# 2       Intersection  0.33
# 3  Accessories Store  0.00
# 4      Luggage Store  0.00
#
#
# ----Fairview, Henry Farm, Oriole----
#                   venue  freq
# 0        Clothing Store  0.14
# 1           Coffee Shop  0.08
# 2  Fast Food Restaurant  0.06
# 3   Japanese Restaurant  0.05
# 4             Juice Bar  0.03
#
#
# ----Glencairn----
#                  venue  freq
# 0                 Park  0.25
# 1                  Pub  0.25
# 2  Japanese Restaurant  0.25
# 3          Pizza Place  0.25
# 4    Accessories Store  0.00
#
#
# ----Hillcrest Village----
#                       venue  freq
# 0                      Pool   0.2
# 1               Golf Course   0.2
# 2                   Dog Run   0.2
# 3        Athletics & Sports   0.2
# 4  Mediterranean Restaurant   0.2
#
#
# ----Humber Summit----
#                  venue  freq
# 0  Empanada Restaurant   0.5
# 1          Pizza Place   0.5
# 2            Pet Store   0.0
# 3                 Park   0.0
# 4        Movie Theater   0.0
#
#
# ----Humberlea, Emery----
#                venue  freq
# 0     Baseball Field   1.0
# 1  Accessories Store   0.0
# 2             Lounge   0.0
# 3           Pharmacy   0.0
# 4          Pet Store   0.0
#
#
# ----Humewood-Cedarvale----
#           venue  freq
# 0         Trail  0.25
# 1  Hockey Arena  0.25
# 2         Field  0.25
# 3  Tennis Court  0.25
# 4   Men's Store  0.00
#
#
# ----Lawrence Manor, Lawrence Heights----
#                     venue  freq
# 0          Clothing Store  0.25
# 1  Furniture / Home Store  0.17
# 2       Accessories Store  0.08
# 3             Coffee Shop  0.08
# 4                Boutique  0.08
#
#
# ----Leaside----
#                  venue  freq
# 0  Sporting Goods Shop  0.09
# 1          Coffee Shop  0.09
# 2     Sushi Restaurant  0.06
# 3         Burger Joint  0.06
# 4                 Bank  0.06
#
#
# ----North Park, Maple Leaf Park, Upwood Park----
#                         venue  freq
# 0  Construction & Landscaping  0.25
# 1                        Park  0.25
# 2                      Bakery  0.25
# 3            Basketball Court  0.25
# 4          Mexican Restaurant  0.00
#
#
# ----Northwood Park, York University----
#                   venue  freq
# 0           Coffee Shop   0.2
# 1  Caribbean Restaurant   0.2
# 2    Miscellaneous Shop   0.2
# 3                   Bar   0.2
# 4        Massage Studio   0.2
#
#
# ----Parkview Hill, Woodbine Gardens----
#          venue  freq
# 0  Pizza Place  0.17
# 1         Bank  0.08
# 2     Pharmacy  0.08
# 3    Pet Store  0.08
# 4         Café  0.08
#
#
# ----Parkwoods----
#                venue  freq
# 0  Convenience Store  0.33
# 1               Park  0.33
# 2  Food & Drink Shop  0.33
# 3  Accessories Store  0.00
# 4             Lounge  0.00
#
#
# ----Runnymede, The Junction North----
#                venue  freq
# 0      Grocery Store  0.25
# 1  Convenience Store  0.25
# 2           Bus Line  0.25
# 3        Pizza Place  0.25
# 4      Luggage Store  0.00
#
#
# ----Thorncliffe Park----
#                   venue  freq
# 0     Indian Restaurant  0.10
# 1         Grocery Store  0.05
# 2          Liquor Store  0.05
# 3        Discount Store  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----Victoria Village----
#                    venue  freq
# 0            Coffee Shop  0.25
# 1           Hockey Arena  0.25
# 2  Portuguese Restaurant  0.25
# 3           Intersection  0.25
# 4                 Market  0.00
#
#
# ----Willowdale----
#               venue  freq
# 0  Ramen Restaurant  0.08
# 1       Coffee Shop  0.08
# 2       Pizza Place  0.08
# 3    Discount Store  0.05
# 4    Sandwich Place  0.05
#
#
# ----Woodbine Heights----
#           venue  freq
# 0      Pharmacy  0.11
# 1   Video Store  0.11
# 2           Spa  0.11
# 3  Skating Rink  0.11
# 4    Beer Store  0.11
#
#
# ----York Mills West----
#                venue  freq
# 0  Convenience Store  0.33
# 1               Park  0.33
# 2               Bank  0.33
# 3  Accessories Store  0.00
# 4             Lounge  0.00
#
#
# ----York Mills, Silver Hills----
#                venue  freq
# 0          Cafeteria   0.5
# 1  Martial Arts Dojo   0.5
# 2  Accessories Store   0.0
# 3      Luggage Store   0.0
# 4           Pharmacy   0.0

# %%
# create a function to re-order the dataframe with a descending order

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# creare a dataframe containing the top 10 venues in each neighborhood
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = york_grouped['Neighborhood']

for ind in np.arange(york_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(york_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                        Neighborhood 1st Most Common Venue  \
# 0   Bathurst Manor, Wilson Heights, Downsview North                  Bank
# 1                                   Bayview Village    Chinese Restaurant
# 2                 Bedford Park, Lawrence Manor East            Restaurant
# 3                               Caledonia-Fairbanks                  Park
# 4  Del Ray, Mount Dennis, Keelsdale and Silverthorn           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop           Gas Station           Supermarket
# 1   Japanese Restaurant                  Café                  Bank
# 2        Sandwich Place    Italian Restaurant           Coffee Shop
# 3         Women's Store                Market   Distribution Center
# 4    Turkish Restaurant        Sandwich Place        Discount Store
#
#        5th Most Common Venue       6th Most Common Venue  \
# 0  Middle Eastern Restaurant          Chinese Restaurant
# 1                Yoga Studio            Department Store
# 2           Greek Restaurant           Indian Restaurant
# 3               Concert Hall  Construction & Landscaping
# 4        Distribution Center     Comfort Food Restaurant
#
#   7th Most Common Venue       8th Most Common Venue 9th Most Common Venue  \
# 0   Fried Chicken Joint                    Pharmacy           Pizza Place
# 1        Discount Store                       Diner    Dim Sum Restaurant
# 2                  Café                   Pet Store              Pharmacy
# 3     Convenience Store              Cosmetics Shop           Curling Ice
# 4          Concert Hall  Construction & Landscaping     Convenience Store
#
#   10th Most Common Venue
# 0          Deli / Bodega
# 1           Dessert Shop
# 2            Pizza Place
# 3          Deli / Bodega
# 4         Cosmetics Shop

# %% [markdown]
# #### Clustering

# %%
# set number of clusters
kclusters = 5

york_grouped_clustering = york_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(york_grouped_clustering)

kmeans.labels_
# Out:
# array([0, 0, 0, 2, 0, 0, 0, 2, 0, 0, 0, 4, 1, 0, 0, 0, 0, 0, 0, 2, 0, 0,
#        0, 0, 0, 2, 3])

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

york_merged = york_data

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
york_merged = york_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
#
#          2nd Most Common Venue   3rd Most Common Venue  \
# 0            Convenience Store       Food & Drink Shop
# 1        Portuguese Restaurant            Hockey Arena
# 2       Furniture / Home Store                Boutique
# 3                  Coffee Shop              Restaurant
# 4                     Pharmacy            Intersection
# 5                  Pizza Place     Japanese Restaurant
# 6                  Coffee Shop              Restaurant
# 7                   Beer Store          Cosmetics Shop
# 8                        Trail                   Field
# 9                Women's Store                  Market
# 10         Sporting Goods Shop  Furniture / Home Store
# 11          Athletics & Sports                    Pool
# 12                 Coffee Shop             Gas Station
# 13                 Yoga Studio            Burger Joint
# 14                 Coffee Shop    Fast Food Restaurant
# 15          Miscellaneous Shop    Caribbean Restaurant
# 16           Convenience Store            Intersection
# 17         Japanese Restaurant                    Café
# 18               Grocery Store          Baseball Field
# 19           Martial Arts Dojo             Yoga Studio
# 20               Grocery Store          Baseball Field
# 21  Construction & Landscaping                  Bakery
# 22         Empanada Restaurant     Distribution Center
# 23                         NaN                     NaN
# 24               Grocery Store          Baseball Field
# 25              Sandwich Place      Italian Restaurant
# 26          Turkish Restaurant          Sandwich Place
# 27                 Yoga Studio       Electronics Store
# 28            Ramen Restaurant             Pizza Place
# 29               Grocery Store          Baseball Field
# 30                 Pizza Place       Convenience Store
# 31                         NaN                     NaN
# 32           Convenience Store                    Bank
# 33            Ramen Restaurant             Pizza Place
#
#        4th Most Common Venue       5th Most Common Venue  \
# 0                Yoga Studio         Distribution Center
# 1               Intersection                 Yoga Studio
# 2                Event Space          Miscellaneous Shop
# 3                        Gym         Japanese Restaurant
# 4                   Bus Line                   Pet Store
# 5                        Pub               Deli / Bodega
# 6                        Gym         Japanese Restaurant
# 7                Curling Ice                Skating Rink
# 8               Tennis Court                 Yoga Studio
# 9        Distribution Center                Concert Hall
# 10              Burger Joint                        Bank
# 11  Mediterranean Restaurant                 Golf Course
# 12               Supermarket   Middle Eastern Restaurant
# 13               Gas Station        Fast Food Restaurant
# 14       Japanese Restaurant                        Bank
# 15            Massage Studio                         Bar
# 16               Yoga Studio                     Dog Run
# 17                      Bank                 Yoga Studio
# 18                      Bank               Shopping Mall
# 19       Distribution Center                Concert Hall
# 20                      Bank               Shopping Mall
# 21          Basketball Court                     Dog Run
# 22   Comfort Food Restaurant                Concert Hall
# 23                       NaN                         NaN
# 24                      Bank               Shopping Mall
# 25               Coffee Shop            Greek Restaurant
# 26            Discount Store         Distribution Center
# 27              Concert Hall  Construction & Landscaping
# 28            Discount Store                  Restaurant
# 29                      Bank               Shopping Mall
# 30                  Bus Line                 Yoga Studio
# 31                       NaN                         NaN
# 32               Yoga Studio                     Dog Run
# 33            Discount Store                  Restaurant
#
#          6th Most Common Venue       7th Most Common Venue  \
# 0                 Concert Hall  Construction & Landscaping
# 1             Department Store                       Diner
# 2                  Coffee Shop           Accessories Store
# 3             Asian Restaurant          Athletics & Sports
# 4                    Gastropub        Gym / Fitness Center
# 5                        Diner          Dim Sum Restaurant
# 6             Asian Restaurant          Athletics & Sports
# 7                          Spa                       Diner
# 8                Deli / Bodega                       Diner
# 9   Construction & Landscaping           Convenience Store
# 10            Sushi Restaurant               Shopping Mall
# 11         Fried Chicken Joint                       Diner
# 12          Chinese Restaurant         Fried Chicken Joint
# 13               Grocery Store                         Gym
# 14                      Bakery                    Tea Room
# 15         Distribution Center  Construction & Landscaping
# 16                Concert Hall  Construction & Landscaping
# 17            Department Store              Discount Store
# 18              Discount Store                       Hotel
# 19  Construction & Landscaping           Convenience Store
# 20              Discount Store                       Hotel
# 21                Concert Hall           Convenience Store
# 22  Construction & Landscaping           Convenience Store
# 23                         NaN                         NaN
# 24              Discount Store                       Hotel
# 25           Indian Restaurant                        Café
# 26     Comfort Food Restaurant                Concert Hall
# 27           Convenience Store              Cosmetics Shop
# 28            Sushi Restaurant              Sandwich Place
# 29              Discount Store                       Hotel
# 30         Distribution Center                Concert Hall
# 31                         NaN                         NaN
# 32                Concert Hall  Construction & Landscaping
# 33            Sushi Restaurant              Sandwich Place
#
#          8th Most Common Venue       9th Most Common Venue  \
# 0               Cosmetics Shop                 Curling Ice
# 1           Dim Sum Restaurant                Dessert Shop
# 2                Women's Store       Vietnamese Restaurant
# 3                 Concert Hall          Italian Restaurant
# 4           Athletics & Sports                        Bank
# 5                 Dessert Shop            Department Store
# 6                 Concert Hall          Italian Restaurant
# 7                         Park                 Video Store
# 8           Dim Sum Restaurant                Dessert Shop
# 9               Cosmetics Shop                 Curling Ice
# 10                  Sports Bar                   Pet Store
# 11                Concert Hall  Construction & Landscaping
# 12                    Pharmacy                 Pizza Place
# 13        Gym / Fitness Center              Discount Store
# 14                   Juice Bar                  Food Court
# 15           Convenience Store              Cosmetics Shop
# 16              Cosmetics Shop                 Curling Ice
# 17                       Diner          Dim Sum Restaurant
# 18                Home Service           Korean Restaurant
# 19              Cosmetics Shop                 Curling Ice
# 20                Home Service           Korean Restaurant
# 21              Cosmetics Shop                 Curling Ice
# 22              Cosmetics Shop                 Curling Ice
# 23                         NaN                         NaN
# 24                Home Service           Korean Restaurant
# 25                   Pet Store                    Pharmacy
# 26  Construction & Landscaping           Convenience Store
# 27                 Curling Ice               Deli / Bodega
# 28                        Café               Movie Theater
# 29                Home Service           Korean Restaurant
# 30  Construction & Landscaping              Cosmetics Shop
# 31                         NaN                         NaN
# 32              Cosmetics Shop                 Curling Ice
# 33                        Café               Movie Theater
#
#    10th Most Common Venue
# 0           Deli / Bodega
# 1             Curling Ice
# 2       Electronics Store
# 3          Sandwich Place
# 4    Fast Food Restaurant
# 5             Yoga Studio
# 6          Sandwich Place
# 7       Fish & Chips Shop
# 8        Department Store
# 9           Deli / Bodega
# 10       Department Store
# 11              Gastropub
# 12          Deli / Bodega
# 13           Liquor Store
# 14           Dessert Shop
# 15            Curling Ice
# 16          Deli / Bodega
# 17           Dessert Shop
# 18   Gym / Fitness Center
# 19          Deli / Bodega
# 20   Gym / Fitness Center
# 21          Deli / Bodega
# 22          Deli / Bodega
# 23                    NaN
# 24   Gym / Fitness Center
# 25            Pizza Place
# 26         Cosmetics Shop
# 27       Department Store
# 28  Indonesian Restaurant
# 29   Gym / Fitness Center
# 30            Curling Ice
# 31                    NaN
# 32          Deli / Bodega
# 33  Indonesian Restaurant

# %%
# some neighborhoods do not have labels, need to be removed before showing in the map
york_merged.drop(york_merged[pd.isna(york_merged['Cluster Labels'])==True].index, inplace=True)
york_merged.reset_index(drop=True, inplace=True)

# %%
york_merged['Cluster Labels'] = york_merged['Cluster Labels'].astype('int')
york_merged.head()
# Out:
#   Postalcode     Borough                      Neighborhood   Latitude  \
# 0        M3A  North York                         Parkwoods  43.753259
# 1        M4A  North York                  Victoria Village  43.725882
# 2        M6A  North York  Lawrence Manor, Lawrence Heights  43.718518
# 3        M3B  North York                         Don Mills  43.745906
# 4        M4B   East York   Parkview Hill, Woodbine Gardens  43.706397
#
#    Longitude  Cluster Labels 1st Most Common Venue   2nd Most Common Venue  \
# 0 -79.329656               2                  Park       Convenience Store
# 1 -79.315572               0           Coffee Shop   Portuguese Restaurant
# 2 -79.464763               0        Clothing Store  Furniture / Home Store
# 3 -79.352188               0            Beer Store             Coffee Shop
# 4 -79.309937               0           Pizza Place                Pharmacy
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0     Food & Drink Shop           Yoga Studio   Distribution Center
# 1          Hockey Arena          Intersection           Yoga Studio
# 2              Boutique           Event Space    Miscellaneous Shop
# 3            Restaurant                   Gym   Japanese Restaurant
# 4          Intersection              Bus Line             Pet Store
#
#   6th Most Common Venue       7th Most Common Venue 8th Most Common Venue  \
# 0          Concert Hall  Construction & Landscaping        Cosmetics Shop
# 1      Department Store                       Diner    Dim Sum Restaurant
# 2           Coffee Shop           Accessories Store         Women's Store
# 3      Asian Restaurant          Athletics & Sports          Concert Hall
# 4             Gastropub        Gym / Fitness Center    Athletics & Sports
#
#    9th Most Common Venue 10th Most Common Venue
# 0            Curling Ice          Deli / Bodega
# 1           Dessert Shop            Curling Ice
# 2  Vietnamese Restaurant      Electronics Store
# 3     Italian Restaurant         Sandwich Place
# 4                   Bank   Fast Food Restaurant

# %%
# create map
york_map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(york_merged['Latitude'], york_merged['Longitude'], york_merged['Neighborhood'], york_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(york_map_clusters)
       
york_map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
york_merged.loc[york_merged['Cluster Labels'] == 0, york_merged.columns[[1] + list(range(5, york_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue  \
# 1   North York               0           Coffee Shop
# 2   North York               0        Clothing Store
# 3   North York               0            Beer Store
# 4    East York               0           Pizza Place
# 5   North York               0                  Park
# 6   North York               0            Beer Store
# 7    East York               0              Pharmacy
# 8         York               0          Hockey Arena
# 10   East York               0           Coffee Shop
# 11  North York               0               Dog Run
# 12  North York               0                  Bank
# 13   East York               0     Indian Restaurant
# 14  North York               0        Clothing Store
# 15  North York               0           Coffee Shop
# 17  North York               0    Chinese Restaurant
# 18  North York               0                  Park
# 20  North York               0                  Park
# 21  North York               0                  Park
# 23  North York               0                  Park
# 24  North York               0            Restaurant
# 25        York               0           Coffee Shop
# 27  North York               0           Coffee Shop
# 28  North York               0                  Park
# 29        York               0         Grocery Store
# 31  North York               0           Coffee Shop
#
#          2nd Most Common Venue   3rd Most Common Venue  \
# 1        Portuguese Restaurant            Hockey Arena
# 2       Furniture / Home Store                Boutique
# 3                  Coffee Shop              Restaurant
# 4                     Pharmacy            Intersection
# 5                  Pizza Place     Japanese Restaurant
# 6                  Coffee Shop              Restaurant
# 7                   Beer Store          Cosmetics Shop
# 8                        Trail                   Field
# 10         Sporting Goods Shop  Furniture / Home Store
# 11          Athletics & Sports                    Pool
# 12                 Coffee Shop             Gas Station
# 13                 Yoga Studio            Burger Joint
# 14                 Coffee Shop    Fast Food Restaurant
# 15          Miscellaneous Shop    Caribbean Restaurant
# 17         Japanese Restaurant                    Café
# 18               Grocery Store          Baseball Field
# 20               Grocery Store          Baseball Field
# 21  Construction & Landscaping                  Bakery
# 23               Grocery Store          Baseball Field
# 24              Sandwich Place      Italian Restaurant
# 25          Turkish Restaurant          Sandwich Place
# 27            Ramen Restaurant             Pizza Place
# 28               Grocery Store          Baseball Field
# 29                 Pizza Place       Convenience Store
# 31            Ramen Restaurant             Pizza Place
#
#        4th Most Common Venue      5th Most Common Venue  \
# 1               Intersection                Yoga Studio
# 2                Event Space         Miscellaneous Shop
# 3                        Gym        Japanese Restaurant
# 4                   Bus Line                  Pet Store
# 5                        Pub              Deli / Bodega
# 6                        Gym        Japanese Restaurant
# 7                Curling Ice               Skating Rink
# 8               Tennis Court                Yoga Studio
# 10              Burger Joint                       Bank
# 11  Mediterranean Restaurant                Golf Course
# 12               Supermarket  Middle Eastern Restaurant
# 13               Gas Station       Fast Food Restaurant
# 14       Japanese Restaurant                       Bank
# 15            Massage Studio                        Bar
# 17                      Bank                Yoga Studio
# 18                      Bank              Shopping Mall
# 20                      Bank              Shopping Mall
# 21          Basketball Court                    Dog Run
# 23                      Bank              Shopping Mall
# 24               Coffee Shop           Greek Restaurant
# 25            Discount Store        Distribution Center
# 27            Discount Store                 Restaurant
# 28                      Bank              Shopping Mall
# 29                  Bus Line                Yoga Studio
# 31            Discount Store                 Restaurant
#
#       6th Most Common Venue       7th Most Common Venue  \
# 1          Department Store                       Diner
# 2               Coffee Shop           Accessories Store
# 3          Asian Restaurant          Athletics & Sports
# 4                 Gastropub        Gym / Fitness Center
# 5                     Diner          Dim Sum Restaurant
# 6          Asian Restaurant          Athletics & Sports
# 7                       Spa                       Diner
# 8             Deli / Bodega                       Diner
# 10         Sushi Restaurant               Shopping Mall
# 11      Fried Chicken Joint                       Diner
# 12       Chinese Restaurant         Fried Chicken Joint
# 13            Grocery Store                         Gym
# 14                   Bakery                    Tea Room
# 15      Distribution Center  Construction & Landscaping
# 17         Department Store              Discount Store
# 18           Discount Store                       Hotel
# 20           Discount Store                       Hotel
# 21             Concert Hall           Convenience Store
# 23           Discount Store                       Hotel
# 24        Indian Restaurant                        Café
# 25  Comfort Food Restaurant                Concert Hall
# 27         Sushi Restaurant              Sandwich Place
# 28           Discount Store                       Hotel
# 29      Distribution Center                Concert Hall
# 31         Sushi Restaurant              Sandwich Place
#
#          8th Most Common Venue       9th Most Common Venue  \
# 1           Dim Sum Restaurant                Dessert Shop
# 2                Women's Store       Vietnamese Restaurant
# 3                 Concert Hall          Italian Restaurant
# 4           Athletics & Sports                        Bank
# 5                 Dessert Shop            Department Store
# 6                 Concert Hall          Italian Restaurant
# 7                         Park                 Video Store
# 8           Dim Sum Restaurant                Dessert Shop
# 10                  Sports Bar                   Pet Store
# 11                Concert Hall  Construction & Landscaping
# 12                    Pharmacy                 Pizza Place
# 13        Gym / Fitness Center              Discount Store
# 14                   Juice Bar                  Food Court
# 15           Convenience Store              Cosmetics Shop
# 17                       Diner          Dim Sum Restaurant
# 18                Home Service           Korean Restaurant
# 20                Home Service           Korean Restaurant
# 21              Cosmetics Shop                 Curling Ice
# 23                Home Service           Korean Restaurant
# 24                   Pet Store                    Pharmacy
# 25  Construction & Landscaping           Convenience Store
# 27                        Café               Movie Theater
# 28                Home Service           Korean Restaurant
# 29  Construction & Landscaping              Cosmetics Shop
# 31                        Café               Movie Theater
#
#    10th Most Common Venue
# 1             Curling Ice
# 2       Electronics Store
# 3          Sandwich Place
# 4    Fast Food Restaurant
# 5             Yoga Studio
# 6          Sandwich Place
# 7       Fish & Chips Shop
# 8        Department Store
# 10       Department Store
# 11              Gastropub
# 12          Deli / Bodega
# 13           Liquor Store
# 14           Dessert Shop
# 15            Curling Ice
# 17           Dessert Shop
# 18   Gym / Fitness Center
# 20   Gym / Fitness Center
# 21          Deli / Bodega
# 23   Gym / Fitness Center
# 24            Pizza Place
# 25         Cosmetics Shop
# 27  Indonesian Restaurant
# 28   Gym / Fitness Center
# 29            Curling Ice
# 31  Indonesian Restaurant

# %%
york_merged.loc[york_merged['Cluster Labels'] == 1, york_merged.columns[[1] + list(range(5, york_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 26  North York               1        Baseball Field           Yoga Studio
#
#    3rd Most Common Venue 4th Most Common Venue       5th Most Common Venue  \
# 26     Electronics Store          Concert Hall  Construction & Landscaping
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 26     Convenience Store        Cosmetics Shop           Curling Ice
#
#    9th Most Common Venue 10th Most Common Venue
# 26         Deli / Bodega       Department Store

# %%
york_merged.loc[york_merged['Cluster Labels'] == 2, york_merged.columns[[1] + list(range(5, york_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0   North York               2                  Park     Convenience Store
# 9         York               2                  Park         Women's Store
# 16   East York               2                  Park     Convenience Store
# 30  North York               2                  Park     Convenience Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0      Food & Drink Shop           Yoga Studio   Distribution Center
# 9                 Market   Distribution Center          Concert Hall
# 16          Intersection           Yoga Studio               Dog Run
# 30                  Bank           Yoga Studio               Dog Run
#
#          6th Most Common Venue       7th Most Common Venue  \
# 0                 Concert Hall  Construction & Landscaping
# 9   Construction & Landscaping           Convenience Store
# 16                Concert Hall  Construction & Landscaping
# 30                Concert Hall  Construction & Landscaping
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0         Cosmetics Shop           Curling Ice          Deli / Bodega
# 9         Cosmetics Shop           Curling Ice          Deli / Bodega
# 16        Cosmetics Shop           Curling Ice          Deli / Bodega
# 30        Cosmetics Shop           Curling Ice          Deli / Bodega

# %%
york_merged.loc[york_merged['Cluster Labels'] == 3, york_merged.columns[[1] + list(range(5, york_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 19  North York               3             Cafeteria     Martial Arts Dojo
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 19           Yoga Studio   Distribution Center          Concert Hall
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 19  Construction & Landscaping     Convenience Store        Cosmetics Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 19           Curling Ice          Deli / Bodega

# %%
york_merged.loc[york_merged['Cluster Labels'] == 4, york_merged.columns[[1] + list(range(5, york_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 22  North York               4           Pizza Place   Empanada Restaurant
#
#    3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 22   Distribution Center  Comfort Food Restaurant          Concert Hall
#
#          6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 22  Construction & Landscaping     Convenience Store        Cosmetics Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 22           Curling Ice          Deli / Bodega
